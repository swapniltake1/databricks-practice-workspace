# %%
print("01_bronze_load entered")

from datetime import datetime

def log(level, msg):
    print(f"[{datetime.now()}] [{level}] {msg}")

log("INFO", "Reading card transactions")

df = spark.table("bankof420.bank_cards.card_transactions")

cnt = df.count()
log("INFO", f"Row count = {cnt}")

log("INFO", "01_bronze_load completed")

dbutils.notebook.exit("BRONZE_OK")

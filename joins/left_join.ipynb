# %%
# %sql
SELECT
    c.customer_id,
    c.full_name,
    a.account_id
FROM bankof420.bank_master.customers c
LEFT JOIN bankof420.bank_core.accounts a
    ON c.customer_id = a.customer_id;

# %% [markdown]
# Python

# %%
customers = spark.table("bankof420.bank_master.customers")
accounts  = spark.table("bankof420.bank_core.accounts")

df_left = customers.join(
    accounts,
    "customer_id",
    "left"
)

df_left.display()
